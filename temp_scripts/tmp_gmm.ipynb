# %%
from sklearn.mixture import GaussianMixture
from scipy import signal
import numpy as np
from sklearn.preprocessing import normalize
import scipy.io as sio
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
data_file = "//mnt/c/Users/azaidi.000/development/neural_data/event_detection/data/Time_Series_N2_long"

# %%
data = sio.loadmat(data_file)
Vp = np.squeeze(data['Vp'])
Vr = np.squeeze(data['Vr'])
Vt = np.squeeze(data['Vt'])

# %%
plt.figure(); plt.subplots(3,1);
plt.subplot(3,1,1); plt.plot(Vp[:10000])
plt.subplot(3,1,2); plt.plot(Vt[:10000])
plt.subplot(3,1,3); plt.plot(Vr[:10000])

# %%
nperseg=64

f, t, data_stft = signal.stft(Vp, fs=1000, nperseg=nperseg, axis=1)
data_stft = np.abs(np.squeeze(data_stft)) # Required for normalization

# %%
data_stft[:,0] = 0

# %%
plt.semilogy(f[:100], data_stft[500,:100])

# %%
from hmmlearn import hmm
