# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/theonlyid/spectral/blob/release/1.1/docs/notebooks/python/data_example.ipynb)
#
# # Example of spectral contrasting with iEEG data

# %%
# Run this cell if running notebook from Google Colab

# clone repo from github
# !git clone --depth 1 https://github.com/theonlyid/spectral.git
# !git checkout release/1.1

# install the package
# %cd spectral
# !python setup.py install

# %%
import numpy as np
from scipy import io as sio
import matplotlib.pyplot as plt
from spectral.data_handling import TsParams, DataArray, Dataset
from spectral import contrast as sc

# %%
data_obj = sio.loadmat(neuraldatasets/neuraldatasets/sz1.mat)
data = data_obj['EEG']
params = TsParams(nperseg=640, noverlap=480)
da = DataArray(data,fs=1000)
ds = Dataset(da, params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fb5a422adbc2> in <module>
# ----> 1 data_obj = sio.loadmat(neuraldatasets/neuraldatasets/sz1.mat)
#       2 data = data_obj['EEG']
#       3 params = TsParams(nperseg=640, noverlap=480)
#       4 da = DataArray(data,fs=1000)
#       5 ds = Dataset(da, params)
#
# NameError: name 'neuraldatasets' is not defined

# %%
# %%time
snr, f = sc.contrast(data, y.astype(int), fs=1000, nperseg=64, noverlap=32)
# Out:
# Obtain normalization array...
# calculating stft...
# normalizing matrices... this may take a few minutes...
# obtaining snr...
# CPU times: user 1min 41s, sys: 6min 32s, total: 8min 14s
# Wall time: 9min 38s

# %%
plt.imshow(snr, origin='bottom');
plt.set_cmap('jet');
plt.colorbar();

# %%
idx = np.where(snr==max(snr.ravel()))
print("optimal band is {} - {} Hz".format(idx[0], idx[1]))
# Out:
# optimal band is [18] - [21] Hz
